# %% [markdown]
# # [Retrieval-based-Voice-Conversion-WebUI](https://github.com/RVC-Project/Retrieval-based-Voice-Conversion-WebUI) Training notebook Pyhton 3.11.13 (tested)

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/zakaria-kabir/Retrieval-based-Voice-Conversion-WebUI/blob/main/Retrieval_based_Voice_Conversion_WebUI_v2_new.ipynb)

# %%
# !python --version
# Out:
# Python 3.11.13

# %%
import os

cpu_count = os.cpu_count()
if cpu_count is not None:
    print(f"Number of CPU cores: {cpu_count}")
else:
    print("Could not determine CPU count")
# Out:
# Number of CPU cores: 32

# %%
# @title #查看显卡
# !nvidia-smi
# Out:
# Fri Apr 24 23:33:49 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.126.09             Driver Version: 580.126.09     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 5060 ...    Off |   00000000:01:00.0  On |                  N/A |
# | N/A   55C    P8             15W /   80W |    6933MiB /   8151MiB |      8%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !apt-get -y install build-essential python3-dev ffmpeg
# %pip uninstall -y jax jaxlib tensorboard tensorflow torch torchaudio torchvision

# %%
ROOT = "/home/zakaria/PersonalWork/Dialect_CLF_wav2vec2_v2/BengDiDa_preparation/rvc_reference_audio/"  # @param {type:"string"}
dependency_processing = 0  # @param {type:"integer"}

# %% [markdown]
# ## **Clone repository**

# %%
! cd "$ROOT" && git clone https://github.com/zakaria-kabir/Retrieval-based-Voice-Conversion-WebUI.git

# %%
RVC_REPO = ROOT + "Retrieval-based-Voice-Conversion-WebUI"

# %% [markdown]
# ## **Install & resolve Dependencies**

# %%
# @title Install Core Dependencies
if dependency_processing == 1:
    # %pip install -r $RVC_REPO/requirements-py311_updated.txt # time consuimg, should have used a dependency conflit resolver

# %% [markdown]
# ## **Download Pretrained Models**

# %%
# @title Download base model

# v1
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/D32k.pth -d $RVC_REPO/assets/pretrained -o D32k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/D40k.pth -d $RVC_REPO/assets/pretrained -o D40k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/D48k.pth -d $RVC_REPO/assets/pretrained -o D48k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/G32k.pth -d $RVC_REPO/assets/pretrained -o G32k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/G40k.pth -d $RVC_REPO/assets/pretrained -o G40k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/G48k.pth -d $RVC_REPO/assets/pretrained -o G48k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/f0D32k.pth -d $RVC_REPO/assets/pretrained -o f0D32k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/f0D40k.pth -d $RVC_REPO/assets/pretrained -o f0D40k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/f0D48k.pth -d $RVC_REPO/assets/pretrained -o f0D48k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/f0G32k.pth -d $RVC_REPO/assets/pretrained -o f0G32k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/f0G40k.pth -d $RVC_REPO/assets/pretrained -o f0G40k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/f0G48k.pth -d $RVC_REPO/assets/pretrained -o f0G48k.pth

# v2
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/D32k.pth -d $RVC_REPO/assets/pretrained_v2 -o D32k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/D40k.pth -d $RVC_REPO/assets/pretrained_v2 -o D40k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/D48k.pth -d $RVC_REPO/assets/pretrained_v2 -o D48k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/G32k.pth -d $RVC_REPO/assets/pretrained_v2 -o G32k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/G40k.pth -d $RVC_REPO/assets/pretrained_v2 -o G40k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/G48k.pth -d $RVC_REPO/assets/pretrained_v2 -o G48k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/f0D32k.pth -d $RVC_REPO/assets/pretrained_v2 -o f0D32k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/f0D40k.pth -d $RVC_REPO/assets/pretrained_v2 -o f0D40k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/f0D48k.pth -d $RVC_REPO/assets/pretrained_v2 -o f0D48k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/f0G32k.pth -d $RVC_REPO/assets/pretrained_v2 -o f0G32k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/f0G40k.pth -d $RVC_REPO/assets/pretrained_v2 -o f0G40k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/f0G48k.pth -d $RVC_REPO/assets/pretrained_v2 -o f0G48k.pth
# Out:
# [#22adab 104MiB/104MiB(100%) CN:0]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 22adab|OK  |       0B/s|/home/zakaria/PersonalWork/Dialect_CLF_wav2vec2_v2/BengDiDa_preparation/rvc_reference_audio/Retrieval-based-Voice-Conversion-WebUI/assets/pretrained/D32k.pth
#
# Status Legend:
# (OK):download completed.
# [#066621 104MiB/104MiB(100%) CN:0]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 066621|OK  |       0B/s|/home/zakaria/PersonalWork/Dialect_CLF_wav2vec2_v2/BengDiDa_preparation/rvc_reference_audio/Retrieval-based-Voice-Conversion-WebUI/assets/pretrained/D40k.pth
#
# Status Legend:
# (OK):download completed.
# [#3c6888 104MiB/104MiB(100%) CN:0]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# ...

# %%
# @title Download the voice separation model
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/uvr5_weights/HP2-人声vocals+非人声instrumentals.pth -d $RVC_REPO/assets/uvr5_weights -o HP2-人声vocals+非人声instrumentals.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/uvr5_weights/HP5-主旋律人声vocals+其他instrumentals.pth -d $RVC_REPO/assets/uvr5_weights -o HP5-主旋律人声vocals+其他instrumentals.pth
# Out:
# [#08e9d3 60MiB/60MiB(100%) CN:0]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 08e9d3|OK  |       0B/s|/home/zakaria/PersonalWork/Dialect_CLF_wav2vec2_v2/BengDiDa_preparation/rvc_reference_audio/Retrieval-based-Voice-Conversion-WebUI/assets/uvr5_weights/HP2-人声vocals+非人声instrumentals.pth
#
# Status Legend:
# (OK):download completed.
# [#140bf4 60MiB/60MiB(100%) CN:0]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 140bf4|OK  |       0B/s|/home/zakaria/PersonalWork/Dialect_CLF_wav2vec2_v2/BengDiDa_preparation/rvc_reference_audio/Retrieval-based-Voice-Conversion-WebUI/assets/uvr5_weights/HP5-主旋律人声vocals+其他instrumentals.pth
#
# Status Legend:
# (OK):download completed.

# %%
# @title Download hubert_base
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/hubert_base.pt -d $RVC_REPO/assets/hubert/ -o hubert_base.pt
# Out:
# [#0f4214 180MiB/180MiB(100%) CN:0]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 0f4214|OK  |       0B/s|/home/zakaria/PersonalWork/Dialect_CLF_wav2vec2_v2/BengDiDa_preparation/rvc_reference_audio/Retrieval-based-Voice-Conversion-WebUI/assets/hubert//hubert_base.pt
#
# Status Legend:
# (OK):download completed.

# %%
# @title Download rmvpe model
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/rmvpe.pt -d $RVC_REPO/assets/rmvpe/ -o rmvpe.pt
# Out:
# [#792c80 172MiB/172MiB(100%) CN:0]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 792c80|OK  |       0B/s|/home/zakaria/PersonalWork/Dialect_CLF_wav2vec2_v2/BengDiDa_preparation/rvc_reference_audio/Retrieval-based-Voice-Conversion-WebUI/assets/rmvpe//rmvpe.pt
#
# Status Legend:
# (OK):download completed.

# %% [markdown]
# ## **Dataset Setup**

# %%
from google.colab import drive

drive.mount("/content/drive")

# %%
# @title Load the packaged dataset from Google Drive to Colab local SSD

DATASET = "/content/drive/MyDrive/mabk_r_n_d/Project & Learning/Projects/bengali_dialect/BengDiDa/rvc_speaker_audio/sp001.tar.xz"

# !mkdir -p /content/dataset
# move to local ssd
# !rsync -ah --info=progress2 "$DATASET" /content/dataset/

# extract tar.xz
# !tar -xJvf "$DATASET" -C /content/dataset

# %% [markdown]
# ## **Train**

# %%
# @title ⚙️ RVC Training Settings

MODELNAME = "sp001"  # @param {type:"string"}
DATASET_PATH = f"/content/dataset/{MODELNAME}"

SAMPLE_RATE = "48k"  # @param ["32k","40k","48k"]
SAMPLE_RATE_NUM = int(SAMPLE_RATE.replace("k", "")) * 1000

F0_METHOD = "rmvpe"  # @param ["rmvpe","harvest","dio"]

GPU = "0"  # @param {type:"string"}
BATCHSIZE = 16  # @param {type:"integer"}

TOTAL_EPOCH = 300  # @param {type:"integer"}
SAVE_EVERY = 20  # @param {type:"integer"}

DRIVE_BACKUP_ROOT = "/content/drive/MyDrive/mabk_r_n_d/Project & Learning/Projects/bengali_dialect/BengDiDa/rvc_speaker_audio/RVC_model_BackUPS"  # @param {type:"string"}

import os

THREADS = max(1, os.cpu_count())
# THREADS = 8  # @param {type:"integer"}

import torch

DEVICE = f"cuda:{GPU}" if torch.cuda.is_available() else "cpu"

# %%
# @title Preprocess dataset

! mkdir -p "$RVC_REPO/logs/$MODELNAME"
! [ -f "$RVC_REPO/logs/$MODELNAME/preprocess.log" ] || touch "$RVC_REPO/logs/$MODELNAME/preprocess.log"
! cd $RVC_REPO && python infer/modules/train/preprocess.py $DATASET_PATH $SAMPLE_RATE_NUM $THREADS $RVC_REPO/logs/$MODELNAME False 3.7

# %%
# @title Extract f0
! cd $RVC_REPO && python infer/modules/train/extract/extract_f0_print.py $RVC_REPO/logs/$MODELNAME $THREADS $F0_METHOD


# @title Extract features
! cd $RVC_REPO && python infer/modules/train/extract_feature_print.py $DEVICE 1 0 0 $RVC_REPO/logs/$MODELNAME v2 True

# %% [markdown]
# **Train**

# %%
#  @title not tested
# from google.colab import drive
# import shutil
# import glob
# import os

# drive.mount('/content/drive')

# MODELNAME_TO_RESUME = "sp001_test"
# DRIVE_RVC_PATH = "/content/drive/MyDrive/RVC_Models"
# MODEL_DRIVE_FOLDER = f"{DRIVE_RVC_PATH}/{MODELNAME_TO_RESUME}"
# print(f"📦 Restoring {MODELNAME_TO_RESUME} to Colab Environment...")
# # Create target directories
# os.makedirs(f"/content/Retrieval-based-Voice-Conversion-WebUI/assets/weights/", exist_ok=True)
# os.makedirs(f"/content/Retrieval-based-Voice-Conversion-WebUI/assets/indices/", exist_ok=True)
# os.makedirs(f"/content/Retrieval-based-Voice-Conversion-WebUI/logs/{MODELNAME_TO_RESUME}", exist_ok=True)
# # 1. Restore all weights (small pth files)
# for f in glob.glob(f"{MODEL_DRIVE_FOLDER}/{MODELNAME_TO_RESUME}*.pth"):
#     # If it's a giant G_ or D_ file, it goes to logs. If it's a small weight, it goes to weights.
#     if "G_" in f or "D_" in f:
#         shutil.copy2(f, f"/content/Retrieval-based-Voice-Conversion-WebUI/logs/{MODELNAME_TO_RESUME}/")
#     else:
#         shutil.copy2(f, "/content/Retrieval-based-Voice-Conversion-WebUI/assets/weights/")
# # 2. Restore Index
# for f in glob.glob(f"{MODEL_DRIVE_FOLDER}/*.index"):
#     shutil.copy2(f, "/content/Retrieval-based-Voice-Conversion-WebUI/assets/indices/")
# # 3. Restore Config/Filelist
# for f in ["config.json", "filelist.txt"]:
#     if os.path.exists(f"{MODEL_DRIVE_FOLDER}/{f}"):
#         shutil.copy2(f"{MODEL_DRIVE_FOLDER}/{f}", f"/content/Retrieval-based-Voice-Conversion-WebUI/logs/{MODELNAME_TO_RESUME}/")
# print("✨ Environment restored. You can now Resume Training or use the WebUI Inference!")

# %%
# @title 1. First run the preparation script to generate filelist.txt and config.json
! cd $RVC_REPO && python prepare_train.py -e {MODELNAME} -sr {SAMPLE_RATE} -f0 1 -v v2

# %%
import subprocess

result = subprocess.run(
    f"cd {RVC_REPO} && ls logs/{MODELNAME}/G_*.pth 2>/dev/null | sort -V | tail -n 1",
    shell=True,
    capture_output=True,
    text=True,
)
LATEST = result.stdout.strip()
if LATEST:
    print(f"Resuming from {LATEST}")
else:
    print("Starting new training")

# %%
# @title 2. Train model

! cd $RVC_REPO && python infer/modules/train/train.py \
    -e {MODELNAME} \
    -sr {SAMPLE_RATE} \
    -f0 1 \
    -bs {BATCHSIZE} \
    -g {GPU} \
    -te {TOTAL_EPOCH} \
    -se {SAVE_EVERY} \
    -pg assets/pretrained_v2/f0G{SAMPLE_RATE}.pth \
    -pd assets/pretrained_v2/f0D{SAMPLE_RATE}.pth \
    -l 0 -c 0 -sw 1 -v v2

# %%
# @title 3. Build FAISS Indices
! cd $RVC_REPO && python train_index.py -e {MODELNAME} -v v2

# %% [markdown]
# ## **plot training metrics**

# %%
import os, re
import pandas as pd
import matplotlib.pyplot as plt

logfile = "/content/Retrieval-based-Voice-Conversion-WebUI/logs/sp001/train.log"
print(os.path.exists(logfile))

rows = []

# Adjusted regex to match your log lines with timestamp and spaces
pattern = re.compile(
    r".*loss_disc=([\d\.]+),\s*loss_gen=([\d\.]+),\s*loss_fm=([\d\.]+),\s*loss_mel=([\d\.]+),\s*loss_kl=([\d\.]+)"
)

with open(logfile, "r", encoding="utf-8") as f:
    for ln in f:
        m = pattern.search(ln)
        if m:
            rows.append(
                {
                    "loss_disc": float(m.group(1)),
                    "loss_gen": float(m.group(2)),
                    "loss_fm": float(m.group(3)),
                    "loss_mel": float(m.group(4)),
                    "loss_kl": float(m.group(5)),
                }
            )

df = pd.DataFrame(rows)
if df.empty:
    print("No loss lines found. Check regex or log content!")
else:
    df.index.name = "step"  # just use row number as step
    df[["loss_mel", "loss_fm", "loss_gen", "loss_disc", "loss_kl"]].plot(
        subplots=False, figsize=(10, 5)
    )
    plt.yscale("linear")
    plt.grid(True)
    plt.show()

# %% [markdown]
# ## **webui**

# %%
# %cd $RVC_REPO
# %load_ext tensorboard
# %tensorboard --logdir /content/Retrieval-based-Voice-Conversion-WebUI/logs
# !python3 infer-web.py --colab --pycmd python3

# %% [markdown]
# **⚠️**

# %% [markdown]
# ## **BackUp To Drive**

# %%
from google.colab import drive
import shutil
import glob
import os


MODELNAME = MODELNAME  #### change
DRIVE_RVC_PATH = DRIVE_BACKUP_ROOT  #### change
MODEL_DRIVE_FOLDER = f"{DRIVE_RVC_PATH}/{MODELNAME}"

os.makedirs(MODEL_DRIVE_FOLDER, exist_ok=True)
print(f"Backing up all files for {MODELNAME}...")

# 1. Backup EVERY small inference weight (for testing quality)
# These are the small files (e100.pth, e120.pth) created by -sw 1
weight_files = glob.glob(
    f"/content/Retrieval-based-Voice-Conversion-WebUI/assets/weights/{MODELNAME}*.pth"
)
if weight_files:
    for f in weight_files:
        shutil.copy2(f, MODEL_DRIVE_FOLDER)
    print(
        f"✅ Backed up {len(weight_files)} inference weights (for testing different epochs)."
    )

# 2. Backup ONLY the LATEST giant training checkpoints (for resuming)
log_dir = f"/content/Retrieval-based-Voice-Conversion-WebUI/logs/{MODELNAME}"
if os.path.exists(log_dir):
    g_files = glob.glob(f"{log_dir}/G_*.pth")
    d_files = glob.glob(f"{log_dir}/D_*.pth")
    if g_files and d_files:
        latest_g = sorted(g_files, key=lambda x: int(x.split("_")[-1].split(".")[0]))[
            -1
        ]
        latest_d = sorted(d_files, key=lambda x: int(x.split("_")[-1].split(".")[0]))[
            -1
        ]
        shutil.copy2(latest_g, MODEL_DRIVE_FOLDER)
        shutil.copy2(latest_d, MODEL_DRIVE_FOLDER)
        print(f"✅ Latest resume-points backed up: {os.path.basename(latest_g)}")

# 3. Backup FAISS Index (Necessary for inference)
index_files = glob.glob(
    f"/content/Retrieval-based-Voice-Conversion-WebUI/logs/{MODELNAME}/added_IVF*.index"
)
if index_files:
    shutil.copy2(index_files[0], MODEL_DRIVE_FOLDER, follow_symlinks=True)
    print("✅ FAISS Index backed up.")

# 4. Backup Config/Filelist (Safety)
if os.path.exists(f"{log_dir}/config.json"):
    shutil.copy2(f"{log_dir}/config.json", MODEL_DRIVE_FOLDER)
    shutil.copy2(f"{log_dir}/filelist.txt", MODEL_DRIVE_FOLDER)

print(f"🎉 Backup Complete! All files are safe in: {MODEL_DRIVE_FOLDER}")

# %% [markdown]
# ## **Restore From Drive For Interface**

# %%
MODELNAME_TO_LOAD = MODELNAME  #### change

print(f"Restoring {MODELNAME_TO_LOAD}...")

MODEL_DRIVE_FOLDER = f"{DRIVE_RVC_PATH}/{MODELNAME_TO_LOAD}"

if not os.path.exists(MODEL_DRIVE_FOLDER):
    print(f"❌ ERROR: Cannot find folder {MODEL_DRIVE_FOLDER} on Google Drive.")
else:
    # 1. Restore PyTorch weight into assets/weights
    pth_source = f"{MODEL_DRIVE_FOLDER}/{MODELNAME_TO_LOAD}.pth"
    pth_dest = f"/content/Retrieval-based-Voice-Conversion-WebUI/assets/weights/{MODELNAME_TO_LOAD}.pth"

    os.makedirs(os.path.dirname(pth_dest), exist_ok=True)
    if os.path.exists(pth_source):
        shutil.copy2(pth_source, pth_dest)
        print("✅ Restored PyTorch model weight.")
    else:
        print("⚠️ Warning: No .pth file found in Drive folder.")

    # 2. Restore FAISS index into assets/indices
    index_files = glob.glob(f"{MODEL_DRIVE_FOLDER}/{MODELNAME_TO_LOAD}_IVF*.index")
    index_dest_folder = (
        "/content/Retrieval-based-Voice-Conversion-WebUI/assets/indices/"
    )

    os.makedirs(index_dest_folder, exist_ok=True)
    if index_files:
        for index_file in index_files:
            shutil.copy2(index_file, index_dest_folder)
        print("✅ Restored FAISS index.")
    else:
        print("⚠️ Warning: No .index file found in Drive folder.")

    print("🎉 Restoration complete! You can now launch the UI.")

# %%
# !zip -r /content/s001_rvc.zip \
# /content/Retrieval-based-Voice-Conversion-WebUI/assets/indices \
# /content/Retrieval-based-Voice-Conversion-WebUI/assets/weights \
# /content/Retrieval-based-Voice-Conversion-WebUI/logs \
# -x "*/mute/*"

# %%
# !tar --exclude='*/mute/*' -cf /content/s001_rvc.tar \
# -C /content Retrieval-based-Voice-Conversion-WebUI/assets/indices \
# -C /content Retrieval-based-Voice-Conversion-WebUI/assets/weights \
# -C /content Retrieval-based-Voice-Conversion-WebUI/logs
